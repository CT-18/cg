# %% [markdown]
# # Триангуляция Делоне

# %% [markdown]
# Для начала определимся с терминологией.
#
# >**Триангуляция** заданного набора точек $S$ - это такое разбиение выпуклой оболочки этих точек на треугольники, что множество вершин треугольников совпадает с $S$, любые два треугольника не пересекаются и любая точка из выпуклой оболочки принадлежит какому-нибудь треугольнику.
#
# >**Критерий Делоне**: для любого треугольника нет точек из $S$, которые бы лежали внутри описанной около него окружности.
#
# Собственно, **триангуляцией Делоне** назовем такую триангуляцию, для которой выполняется критерий Делоне

# %% [markdown]
# Кроме глобального китерия Делоне, определенного выше, существует локальный критерий Делоне, а также критерии Делоне для ребер.
#
# >**Локальный критерий Делоне**: внутри окружности, описанной около треугольника, не лежат противолежащие ему вершины соседних треугольников.
#
# >**Глобальный критерий Делоне для ребра**: на ребре можно построить такую окружность, что внутри неё не будет точек из $S$.
#
# >**Локальный критерий Делоне для ребра**: на ребре можно построить такую окружность, что внутри неё не будет вершин, противолежащих ребру.
#
# Необходимо доказать равносильность данных критериев.

# %% [markdown]
# ### Лемма 1 (о равносильности критериев Делоне для треугольников)
# > Локальный и глобальный критерии Делоне для треугольников равносильны
#
# $\triangleright$
#
# <div style="padding-left:27px">
#
# Из глобального критерия очевидным образом следует локальный.<br>
#
# Докажем в обратную сторону. Пусть для некоторого треугольника выполнен локальный, но не выполнен глобальный критерий. Т.е. существует точка $E$ такая, что лежит внутри описанной окружности и не имеет рёбер с вершинами треугольника. Зафиксируем эту точку и из всех таких треугольников рассмотрим тот, у которого $\angle BEC$ максимален, если $BC$ - ближайшая к точке $E$ сторона. Пусть с таким $\Delta ABC$ соседствует $\Delta BCD$. <br>
#
# Точка $E$ не может лежать внутри $\Delta BCD$, так как в этом случае имелись бы рёбра $EB$ и $EC$, и нарушался бы локальный критерий. Значит, она снаружи. Не уменьшая общности, будем считать, что $CD$ - ближайшая к $E$ сторона $\Delta BCD$. Тогда выполнено, что $\angle BAC + \angle BEC > 180°, \angle BAC + \angle BDC < 180°$. Если т.$E$ лежит вне окружности, описанной около $\Delta BCD$, то $\angle BEC < \angle BDC$, что противоречит неравенствам выше. Значит, для $\Delta BCD$ также нарушается глобальный критерий. Из вышесказанного следует, что $\angle CED > \angle BEC$, где $CD$ - ближайшая к $E$ сторона. Противоречие.
#
# </div>
#
# $\triangleleft$

# %% [markdown]
# ### Лемма 2 (о равносильности критериев Делоне для рёбер)
# > Локальный и глобальный критерии Делоне для рёбер равносильны
#
# $\triangleright$
#
# <div style="padding-left:40px">
#
# Из глобального критерия очевидным образом следует локальный.<br>
#
# Докажем в обратную сторону. Пусть для некоторого ребра выполнен локальный, но не выполнен глобальный критерий. Т.е. существует такая точка, что лежит внутри любой описанной окружности и не образует треугольника с вершинами "плохого" ребра. Зафиксируем эту точку $D$ и из всех таких рёбер рассмотрим тот, у которого $\angle ADB$ максимален, где $AB$ - это ребро. Пусть это ребро со стороны точки $D$ лежит в $\Delta ABC$. <br>
#
# Точка $D$ не может лежать внутри $\Delta ABC$, так как в этом случае имелись бы рёбра $AD$ и $BD$, и нарушался бы локальный критерий. Значит, она снаружи. Не уменьшая общности, будем считать, что $BC$ - ближайшая к $D$ сторона $\Delta ABC$. Относительно прямой $AD$ точки $B$ и $C$ лежат в разных полуплоскостях, а значит, $\angle BDC = \angle BDA + \angle ADC$. Отсюда $\angle BDC > \angle BDA$. Точка $D$ также не образует треугольника с ребром $BC$ и будет лежать в любой окружности, опирающейся на ребро $BC$ и не содержащей точку $A$, противолежащую ребру. Значит, при выборе ребра $AB$ мы должны были выбрать ребро $BC$. Противоречие.
#
# </div>
#
# $\triangleleft$

# %% [markdown]
# ### Лемма 3 (о равносильности глобальных критериев Делоне)
# > Глобальные критерии Делоне для треугольников и для рёбер равносильны
#
# $\triangleright$
#
# <div style="padding-left:40px">
#
# Из критерия для треугольников очевидным образом следует критерий для рёбер. Достаточно в качестве необходимой окружности взять окружность одного из треугольников, содержащих противолежащую точку.<br>
#
# Докажем в обратную сторону. Пусть для всех рёбер выполнен глобальный критерий Делоне, но есть $\Delta ABC$, чья описанная окружность содержит какую-либо точку $D$ из набора  $S$. Пусть $BC$ - ближайшее к точке $D$ ребро. Для него выполнено $\angle BAC + \angle BDC > 180°$. Из этого следует, что невозможно построить окружность, не содержащую одновременно точек $A$ и $D$. Значит, есть ребро, для которого не выполнен глобальный критерий Делоне. Противоречие.
#
# </div>
#
# $\triangleleft$

# %% [markdown]
# Из предыдущих трех лемм следует, что **все критерии Делоне равносильны.**

# %% [markdown]
# ## Существование триангуляции Делоне и её построение
# Далее необходимо показать существование триангуляции Делоне для произвольного набора точек. Для этого воспользуемся следующим методом. Поднимем все наши точки в просторанство большей размерности, преобразовав точки по такому закону: $(x, y) \to (x, y, x^2+y^2)$. Тем самым, мы спроецируем наши точки на параболоид $x^2 + y^2 = z$. Далее построим выпуклую оболочку полученных точек, что мы умеем делать за $O(N\log N)$. Грани выпуклой оболочки будут соответствовать треугольникам в нашей триангуляции с некоторыми незначительными поправками.

# %% [markdown]
# ### Лемма 4 (об окружности, спроецированной на параболоид)
# >Все точки окружности, спроецированной на параболоид, находятся в одной плоскости. Точки, лежащие внутри окружности, будут лежать под этой плоскостью. Точки, лежащие вне окружности, будут лежать над плоскостью.
#
# $\triangleright$
#
# <div style="padding-left:40px">
#
# Любая окружность в $R^2$ описывается уравнением $(x-a)^2+(y-b)^2=r^2$, где $(a, b)$ - центр окружности, $r$ - её радиус. <br>
# Раскрываем скобки: $x^2-2ax+a^2+y^2-2by+b^2-r^2=0$. <br>
# Подставляем в уравнение параболоида $(x^2+y^2=z)$: $(-2a)x+(-2b)y+(-1)z+(a^2+b^2-r^2)=0$. <br>
# Получившееся уравнение является уравнением плоскости: $Ax+By+Cz+D=0$. <br>
# Это значит, что все точки, лежащие на одной окружности, при проецировании на параболоид будут лежать в одной плоскости.<br><br>
# Рассмотрим точки внутри этой окружности. Для них $(x-a)^2+(y-b)^2<r^2$. Подставляя в уравнение параболоида, получим $Ax+By+Cz+D<0$, что означает, что точки, лежащие внутри окружности, будут находиться ниже плоскости спроецированной окружности. Аналогично для точек вне окружности.
#
# </div>
#
# $\triangleleft$

# %% [markdown]
# ### Теорема о существовании триангуляции Делоне
# >Триангуляция Делоне существует
#
# $\triangleright$
#
# <div style="padding-left:40px">
#
# 1. Поднимем все точки на параболоид <br>
# 2. Построим выпуклую оболочку <br>
# 3. Если образовались нетреугольные грани - трианулируем их любым образом <br><br>
#
# Все грани выпуклой оболочки окажутся внутри параболоида из-за его выпуклости. При этом точки лежат на параболоиде. Поэтому не найдётся точек, которые будут лежать за гранями выпуклой оболочки. То есть все точки, спроецированные на параболоид, будут принадлежать выпуклой оболочке.
#
# Внутри окружностей, описанных вокруг проекций треугольников выпуклой оболочки, не будет лежать никаких точек по лемме 4. Значит, для проекций треугольников выполнен критерий Делоне. Из этого следует, что получившаяся триангуляция есть триангуляция Делоне.
#
# </div>
#
# $\triangleleft$

# %% [markdown]
# Итого мы получили **алгоритм построения триангуляции Делоне:**

# %% [markdown]
# ## Сведение любой триангуляции к триангуляции Делоне
# флип <br>
# лемма о паре ребер <br>
# лемма о разности объемов <br>
# лемма о сведении <br>

# %% [markdown]
# Для решения этой нам потребуется такая операция, как **флип**
#
# >**Флип (flip)** - это замена одной диагонали на другую в четырёхугольнике, образованном смежными треугольниками.
#
# Будем называть ребро **хорошим**, если для него выполнен локальный критерий Делоне, и **плохим** в обратном случае.
#
# Необходимо показать, что любая триангуляция сводится к триангуляции Делоне за конечное число флипов. Для этого докажем несколько лемм:

# %% [markdown]
# ### Лемма 5 (о хорошем ребре)
# > В любом четырёхугольнике, образованном смежными треугольниками, как минимум одна диагональ является хорошим ребром
#
# $\triangleright$
#
# <div style="padding-left:40px">
#
# Зафиксируем такой четырёхугольник $ABCD$. Пусть $AC$ и $BD$ это плохие рёбра. В окружности, описанной около $\Delta ABC$ содержится точка $D$, так как $AC$ не удовлетворяет локальному критерию Делоне. Значит $\angle ABC + \angle ADC > 180°$. Аналогично показывается, что $\angle BAD + \angle BCD > 180°$. В итоге сумма углов четырёхугольника $ABCD$ больше 360°, что невозможно. Значит хотя бы одна диагональ является хорошим ребром.
#
# </div>
#
# $\triangleleft$

# %% [markdown]
# ### Лемма 6 (о сведении флипами)
# >Любая триангуляция сводится к триангуляции Делоне за конечное число флипов
#
# $\triangleright$
#
# <div style="padding-left:40px">
#
# Рассмотрим все рёбра исходной триангуляции. Их конечное число. Флипнем все плохие рёбра. По лемме 5 все получившиеся рёбра будут хорошими. В итоге все ребра нашей триангуляции будут хорошими. По эквивалентности критериев Делоне для получившейся триангуляции будет выполняться глобальный критерий Делоне, что является определением триангуляции Делоне.
#
# </div>
#
# $\triangleleft$
